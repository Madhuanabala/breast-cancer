# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhuanabala/breast-cancer/blob/feature-selection/SubstructurecountFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('/content/SubstructureCount.csv')
data
# Out:
#                Name  SubFPC1  SubFPC2  SubFPC3  SubFPC4  SubFPC5  SubFPC6  \
# 0      CHEMBL266703        2        4        0        0        1        0
# 1     CHEMBL2145445        2        4        0        0        1        0
# 2      CHEMBL266185        2        4        0        0        1        0
# 3       CHEMBL19195        1        1        0        0        1        0
# 4          CHEMBL83        1        1        0        0        1        0
# ...             ...      ...      ...      ...      ...      ...      ...
# 1812  CHEMBL5440580        1        5        0        1        1        0
# 1813  CHEMBL5417545        1        5        0        1        0        0
# 1814   CHEMBL225542        0        0        0        0        0        0
# 1815  CHEMBL1093100        1        0        0        0        0        0
# 1816   CHEMBL428647        6        2        1        2        1        0
#
#       SubFPC7  SubFPC8  SubFPC9  ...  SubFPC299  SubFPC300  SubFPC301  \
# 0           0        0        0  ...          0         40         40
# 1           0        0        0  ...          0         29         29
# 2           0        0        0  ...          0         37         37
# 3           0        0        0  ...          0          7          7
# 4           0        0        0  ...          0          7          7
# ...       ...      ...      ...  ...        ...        ...        ...
# 1812        0        0        0  ...          0         10         10
# 1813        0        0        0  ...          0          9          9
# 1814        0        0        0  ...          0          3          3
# 1815        0        0        0  ...          0          5          5
# 1816        0        0        0  ...          0         33         33
#
#       SubFPC302  SubFPC303  SubFPC304  SubFPC305  SubFPC306  SubFPC307  \
# 0            26          0          0          0          0         52
# 1            12          0          0          0          0         42
# 2            23          0          0          0          0         52
# 3             7          0          0          0          0         21
# 4             8          0          0          0          0         21
# ...         ...        ...        ...        ...        ...        ...
# 1812          1          1          0          0          0         14
# 1813          1          1          0          0          0         14
# 1814          4          0          0          0          0         19
# 1815          2          0          0          0          0         17
# 1816         15          0          0          0          0         39
#
#       bioactivity_class
# 0                active
# 1                active
# 2                active
# 3              inactive
# 4                active
# ...                 ...
# 1812           inactive
# 1813           inactive
# 1814             active
# 1815           inactive
# 1816             active
#
# [1817 rows x 309 columns]

# %%
data.dtypes
# Out:
# Name                 object
# SubFPC1               int64
# SubFPC2               int64
# SubFPC3               int64
# SubFPC4               int64
#                       ...
# SubFPC304             int64
# SubFPC305             int64
# SubFPC306             int64
# SubFPC307             int64
# bioactivity_class    object
# Length: 309, dtype: object

# %%
data['bioactivity_class'].replace('active', 'P', inplace=True)
data['bioactivity_class'].replace('inactive', 'N', inplace=True)
data.rename(columns = {"bioactivity_class": "bioactivity_class"}, inplace = True)
data
# Out:
# <ipython-input-3-ec92a85df410>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['bioactivity_class'].replace('active', 'P', inplace=True)
# <ipython-input-3-ec92a85df410>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['bioactivity_class'].replace('inactive', 'N', inplace=True)
#                Name  SubFPC1  SubFPC2  SubFPC3  SubFPC4  SubFPC5  SubFPC6  \
# 0      CHEMBL266703        2        4        0        0        1        0
# 1     CHEMBL2145445        2        4        0        0        1        0
# 2      CHEMBL266185        2        4        0        0        1        0
# 3       CHEMBL19195        1        1        0        0        1        0
# 4          CHEMBL83        1        1        0        0        1        0
# ...             ...      ...      ...      ...      ...      ...      ...
# 1812  CHEMBL5440580        1        5        0        1        1        0
# 1813  CHEMBL5417545        1        5        0        1        0        0
# 1814   CHEMBL225542        0        0        0        0        0        0
# 1815  CHEMBL1093100        1        0        0        0        0        0
# 1816   CHEMBL428647        6        2        1        2        1        0
#
#       SubFPC7  SubFPC8  SubFPC9  ...  SubFPC299  SubFPC300  SubFPC301  \
# 0           0        0        0  ...          0         40         40
# 1           0        0        0  ...          0         29         29
# 2           0        0        0  ...          0         37         37
# 3           0        0        0  ...          0          7          7
# 4           0        0        0  ...          0          7          7
# ...       ...      ...      ...  ...        ...        ...        ...
# 1812        0        0        0  ...          0         10         10
# 1813        0        0        0  ...          0          9          9
# 1814        0        0        0  ...          0          3          3
# 1815        0        0        0  ...          0          5          5
# 1816        0        0        0  ...          0         33         33
#
#       SubFPC302  SubFPC303  SubFPC304  SubFPC305  SubFPC306  SubFPC307  \
# 0            26          0          0          0          0         52
# 1            12          0          0          0          0         42
# 2            23          0          0          0          0         52
# 3             7          0          0          0          0         21
# 4             8          0          0          0          0         21
# ...         ...        ...        ...        ...        ...        ...
# 1812          1          1          0          0          0         14
# 1813          1          1          0          0          0         14
# 1814          4          0          0          0          0         19
# 1815          2          0          0          0          0         17
# 1816         15          0          0          0          0         39
#
#       bioactivity_class
# 0                     P
# 1                     P
# 2                     P
# 3                     N
# 4                     P
# ...                 ...
# 1812                  N
# 1813                  N
# 1814                  P
# 1815                  N
# 1816                  P
#
# [1817 rows x 309 columns]

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.dropna(inplace =True)
data.isnull().sum().sum()
# Out:
# 0

# %%
data1 = data.iloc[:,1:308]
data1
data2 = data.iloc[:,-1]

# %%
data1
data2
# Out:
# 0       P
# 1       P
# 2       P
# 3       N
# 4       P
#        ..
# 1812    N
# 1813    N
# 1814    P
# 1815    N
# 1816    P
# Name: bioactivity_class, Length: 1817, dtype: object

# %%
from sklearn.feature_selection import VarianceThreshold
threshold = VarianceThreshold(threshold=.1)
def variance_threshold_selector(data1, threshold=0.10):
    selector = VarianceThreshold(threshold)
    selector.fit(data1)
    return data[data1.columns[selector.get_support(indices=True)]]
data1_HV = variance_threshold_selector(data1)

# %%
data1_HV = variance_threshold_selector(data1)
data1_HV
# Out:
#       SubFPC1  SubFPC2  SubFPC3  SubFPC4  SubFPC5  SubFPC9  SubFPC12  \
# 0           2        4        0        0        1        0         3
# 1           2        4        0        0        1        0         3
# 2           2        4        0        0        1        0         3
# 3           1        1        0        0        1        0         0
# 4           1        1        0        0        1        0         0
# ...       ...      ...      ...      ...      ...      ...       ...
# 1812        1        5        0        1        1        0         0
# 1813        1        5        0        1        0        0         0
# 1814        0        0        0        0        0        0         0
# 1815        1        0        0        0        0        0         0
# 1816        6        2        1        2        1        0         3
#
#       SubFPC14  SubFPC15  SubFPC16  ...  SubFPC286  SubFPC287  SubFPC288  \
# 0            1         1         1  ...          1         18          0
# 1            1         1         0  ...          1         14          0
# 2            1         1         0  ...          1         18          0
# 3            0         0         0  ...          0          6          0
# 4            0         0         0  ...          0          6          0
# ...        ...       ...       ...  ...        ...        ...        ...
# 1812         0         0         0  ...          0          3          0
# 1813         0         0         0  ...          0          3          0
# 1814         0         0         0  ...          0          2          0
# 1815         0         0         0  ...          0          0          0
# 1816         2         1         1  ...          0          4          0
#
#       SubFPC295  SubFPC296  SubFPC300  SubFPC301  SubFPC302  SubFPC303  \
# 0            30          0         40         40         26          0
# 1            21          0         29         29         12          0
# 2            28          0         37         37         23          0
# 3             6          0          7          7          7          0
# 4             5          0          7          7          8          0
# ...         ...        ...        ...        ...        ...        ...
# 1812          8          0         10         10          1          1
# 1813          8          0          9          9          1          1
# 1814         12          0          3          3          4          0
# 1815         10          0          5          5          2          0
# 1816         21          0         33         33         15          0
#
#       SubFPC307
# 0            52
# 1            42
# 2            52
# 3            21
# 4            21
# ...         ...
# 1812         14
# 1813         14
# 1814         19
# 1815         17
# 1816         39
#
# [1817 rows x 54 columns]

# %%
data2_HV = pd.merge(data1_HV,data2,left_index=True,right_index=True)
data2_HV
# Out:
#       SubFPC1  SubFPC2  SubFPC3  SubFPC4  SubFPC5  SubFPC9  SubFPC12  \
# 0           2        4        0        0        1        0         3
# 1           2        4        0        0        1        0         3
# 2           2        4        0        0        1        0         3
# 3           1        1        0        0        1        0         0
# 4           1        1        0        0        1        0         0
# ...       ...      ...      ...      ...      ...      ...       ...
# 1812        1        5        0        1        1        0         0
# 1813        1        5        0        1        0        0         0
# 1814        0        0        0        0        0        0         0
# 1815        1        0        0        0        0        0         0
# 1816        6        2        1        2        1        0         3
#
#       SubFPC14  SubFPC15  SubFPC16  ...  SubFPC287  SubFPC288  SubFPC295  \
# 0            1         1         1  ...         18          0         30
# 1            1         1         0  ...         14          0         21
# 2            1         1         0  ...         18          0         28
# 3            0         0         0  ...          6          0          6
# 4            0         0         0  ...          6          0          5
# ...        ...       ...       ...  ...        ...        ...        ...
# 1812         0         0         0  ...          3          0          8
# 1813         0         0         0  ...          3          0          8
# 1814         0         0         0  ...          2          0         12
# 1815         0         0         0  ...          0          0         10
# 1816         2         1         1  ...          4          0         21
#
#       SubFPC296  SubFPC300  SubFPC301  SubFPC302  SubFPC303  SubFPC307  \
# 0             0         40         40         26          0         52
# 1             0         29         29         12          0         42
# 2             0         37         37         23          0         52
# 3             0          7          7          7          0         21
# 4             0          7          7          8          0         21
# ...         ...        ...        ...        ...        ...        ...
# 1812          0         10         10          1          1         14
# 1813          0          9          9          1          1         14
# 1814          0          3          3          4          0         19
# 1815          0          5          5          2          0         17
# 1816          0         33         33         15          0         39
#
#       bioactivity_class
# 0                     P
# 1                     P
# 2                     P
# 3                     N
# 4                     P
# ...                 ...
# 1812                  N
# 1813                  N
# 1814                  P
# 1815                  N
# 1816                  P
#
# [1817 rows x 55 columns]

# %%
correlated_features_1 = set()
corr_matrix_class = data2_HV.drop(columns=['bioactivity_class']).corr()


for i in range(len(corr_matrix_class.columns)):
    for j in range(i):
        if abs(corr_matrix_class.iloc[i, j]) > 0.9:
            colname = corr_matrix_class.columns[i]
            correlated_features_1.add(colname)
correlated_features_1
# Out:
# {'SubFPC101',
#  'SubFPC14',
#  'SubFPC184',
#  'SubFPC280',
#  'SubFPC283',
#  'SubFPC285',
#  'SubFPC286',
#  'SubFPC301',
#  'SubFPC66'}

# %%
def remove_correlated_features(features, data):
    for x in features:
        data.drop(x, axis=1, inplace=True)
    return data

# %%
data3= remove_correlated_features(correlated_features_1, data2_HV)
data3
# Out:
#       SubFPC1  SubFPC2  SubFPC3  SubFPC4  SubFPC5  SubFPC9  SubFPC12  \
# 0           2        4        0        0        1        0         3
# 1           2        4        0        0        1        0         3
# 2           2        4        0        0        1        0         3
# 3           1        1        0        0        1        0         0
# 4           1        1        0        0        1        0         0
# ...       ...      ...      ...      ...      ...      ...       ...
# 1812        1        5        0        1        1        0         0
# 1813        1        5        0        1        0        0         0
# 1814        0        0        0        0        0        0         0
# 1815        1        0        0        0        0        0         0
# 1816        6        2        1        2        1        0         3
#
#       SubFPC15  SubFPC16  SubFPC18  ...  SubFPC282  SubFPC287  SubFPC288  \
# 0            1         1         2  ...          1         18          0
# 1            1         0         1  ...          1         14          0
# 2            1         0         2  ...          1         18          0
# 3            0         0         0  ...          0          6          0
# 4            0         0         1  ...          0          6          0
# ...        ...       ...       ...  ...        ...        ...        ...
# 1812         0         0         0  ...          0          3          0
# 1813         0         0         0  ...          0          3          0
# 1814         0         0         0  ...          0          2          0
# 1815         0         0         0  ...          0          0          0
# 1816         1         1         0  ...          0          4          0
#
#       SubFPC295  SubFPC296  SubFPC300  SubFPC302  SubFPC303  SubFPC307  \
# 0            30          0         40         26          0         52
# 1            21          0         29         12          0         42
# 2            28          0         37         23          0         52
# 3             6          0          7          7          0         21
# 4             5          0          7          8          0         21
# ...         ...        ...        ...        ...        ...        ...
# 1812          8          0         10          1          1         14
# 1813          8          0          9          1          1         14
# 1814         12          0          3          4          0         19
# 1815         10          0          5          2          0         17
# 1816         21          0         33         15          0         39
#
#       bioactivity_class
# 0                     P
# 1                     P
# 2                     P
# 3                     N
# 4                     P
# ...                 ...
# 1812                  N
# 1813                  N
# 1814                  P
# 1815                  N
# 1816                  P
#
# [1817 rows x 46 columns]

# %%
data3.to_csv('Substructurecount2.csv')

# %%
X = data3.iloc[:,1:45]  #independent columns
X
y = data3.iloc[:,-1]
y   #target column i.e price range
# Out:
# 0       P
# 1       P
# 2       P
# 3       N
# 4       P
#        ..
# 1812    N
# 1813    N
# 1814    P
# 1815    N
# 1816    P
# Name: bioactivity_class, Length: 1817, dtype: object

# %%
X
# Out:
#       SubFPC2  SubFPC3  SubFPC4  SubFPC5  SubFPC9  SubFPC12  SubFPC15  \
# 0           4        0        0        1        0         3         1
# 1           4        0        0        1        0         3         1
# 2           4        0        0        1        0         3         1
# 3           1        0        0        1        0         0         0
# 4           1        0        0        1        0         0         0
# ...       ...      ...      ...      ...      ...       ...       ...
# 1812        5        0        1        1        0         0         0
# 1813        5        0        1        0        0         0         0
# 1814        0        0        0        0        0         0         0
# 1815        0        0        0        0        0         0         0
# 1816        2        1        2        1        0         3         1
#
#       SubFPC16  SubFPC18  SubFPC23  ...  SubFPC281  SubFPC282  SubFPC287  \
# 0            1         2         1  ...          0          1         18
# 1            0         1         1  ...          0          1         14
# 2            0         2         1  ...          0          1         18
# 3            0         0         0  ...          0          0          6
# 4            0         1         1  ...          0          0          6
# ...        ...       ...       ...  ...        ...        ...        ...
# 1812         0         0         0  ...          0          0          3
# 1813         0         0         0  ...          0          0          3
# 1814         0         0         0  ...          0          0          2
# 1815         0         0         0  ...          0          0          0
# 1816         1         0         0  ...          0          0          4
#
#       SubFPC288  SubFPC295  SubFPC296  SubFPC300  SubFPC302  SubFPC303  \
# 0             0         30          0         40         26          0
# 1             0         21          0         29         12          0
# 2             0         28          0         37         23          0
# 3             0          6          0          7          7          0
# 4             0          5          0          7          8          0
# ...         ...        ...        ...        ...        ...        ...
# 1812          0          8          0         10          1          1
# 1813          0          8          0          9          1          1
# 1814          0         12          0          3          4          0
# 1815          0         10          0          5          2          0
# 1816          0         21          0         33         15          0
#
#       SubFPC307
# 0            52
# 1            42
# 2            52
# 3            21
# 4            21
# ...         ...
# 1812         14
# 1813         14
# 1814         19
# 1815         17
# 1816         39
#
# [1817 rows x 44 columns]

# %%
from sklearn.preprocessing import StandardScaler
# y = data['class']
# X_features =data.drop(columns='class')
scaler = StandardScaler()
X_transform = scaler.fit_transform(X)
X_transform_pd = pd.DataFrame(X_transform, columns = X.columns)
X_transform_pd

# #Standardize/normalize the data
# from sklearn.preprocessing import MinMaxScaler
# sc = MinMaxScaler()
# X_transform = sc.fit_transform(X)
# X_transform
# Out:
#        SubFPC2   SubFPC3   SubFPC4   SubFPC5   SubFPC9  SubFPC12  SubFPC15  \
# 0     0.454333 -0.488479 -0.390203  0.480001 -0.227062  1.687391  2.160167
# 1     0.454333 -0.488479 -0.390203  0.480001 -0.227062  1.687391  2.160167
# 2     0.454333 -0.488479 -0.390203  0.480001 -0.227062  1.687391  2.160167
# 3    -0.432056 -0.488479 -0.390203  0.480001 -0.227062 -0.430980 -0.386896
# 4    -0.432056 -0.488479 -0.390203  0.480001 -0.227062 -0.430980 -0.386896
# ...        ...       ...       ...       ...       ...       ...       ...
# 1812  0.749796 -0.488479  0.860235  0.480001 -0.227062 -0.430980 -0.386896
# 1813  0.749796 -0.488479  0.860235 -0.511092 -0.227062 -0.430980 -0.386896
# 1814 -0.727519 -0.488479 -0.390203 -0.511092 -0.227062 -0.430980 -0.386896
# 1815 -0.727519 -0.488479 -0.390203 -0.511092 -0.227062 -0.430980 -0.386896
# 1816 -0.136593  0.405344  2.110673  0.480001 -0.227062  1.687391  2.160167
#
#       SubFPC16  SubFPC18  SubFPC23  ...  SubFPC281  SubFPC282  SubFPC287  \
# 0     1.431626  1.409157  1.255569  ...  -0.138804   1.868388   4.806178
# 1    -0.330748  0.401507  1.255569  ...  -0.138804   1.868388   3.504569
# 2    -0.330748  1.409157  1.255569  ...  -0.138804   1.868388   4.806178
# 3    -0.330748 -0.606143 -0.371656  ...  -0.138804  -0.223332   0.901349
# 4    -0.330748  0.401507  1.255569  ...  -0.138804  -0.223332   0.901349
# ...        ...       ...       ...  ...        ...        ...        ...
# 1812 -0.330748 -0.606143 -0.371656  ...  -0.138804  -0.223332  -0.074859
# 1813 -0.330748 -0.606143 -0.371656  ...  -0.138804  -0.223332  -0.074859
# 1814 -0.330748 -0.606143 -0.371656  ...  -0.138804  -0.223332  -0.400261
# 1815 -0.330748 -0.606143 -0.371656  ...  -0.138804  -0.223332  -1.051066
# 1816  1.431626 -0.606143 -0.371656  ...  -0.138804  -0.223332   0.250544
#
#       SubFPC288  SubFPC295  SubFPC296  SubFPC300  SubFPC302  SubFPC303  \
# 0     -0.226324   2.346288  -0.245422   1.816050    2.58812  -0.364264
# 1     -0.226324   1.183631  -0.245422   1.018200    0.74530  -0.364264
# 2     -0.226324   2.087920  -0.245422   1.598455    2.19323  -0.364264
# 3     -0.226324  -0.754131  -0.245422  -0.577500    0.08715  -0.364264
# 4     -0.226324  -0.883315  -0.245422  -0.577500    0.21878  -0.364264
# ...         ...        ...        ...        ...        ...        ...
# 1812  -0.226324  -0.495763  -0.245422  -0.359905   -0.70263   0.485374
# 1813  -0.226324  -0.495763  -0.245422  -0.432437   -0.70263   0.485374
# 1814  -0.226324   0.020974  -0.245422  -0.867628   -0.30774  -0.364264
# 1815  -0.226324  -0.237395  -0.245422  -0.722564   -0.57100  -0.364264
# 1816  -0.226324   1.183631  -0.245422   1.308327    1.14019  -0.364264
#
#       SubFPC307
# 0      3.458326
# 1      2.377859
# 2      3.458326
# 3      0.108879
# 4      0.108879
# ...         ...
# 1812  -0.647448
# 1813  -0.647448
# 1814  -0.107214
# 1815  -0.323308
# 1816   2.053719
#
# [1817 rows x 44 columns]

# %%
## Split data into train and test sets.
from sklearn.model_selection import train_test_split
seed_num = 10
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.3, random_state=seed_num)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1271, 44)
# (1271,)
# (546, 44)
# (546,)

# %%
X_train
# Out:
#       SubFPC2  SubFPC3  SubFPC4  SubFPC5  SubFPC9  SubFPC12  SubFPC15  \
# 984         3        0        0        0        0         3         1
# 961         1        1        2        0        0         0         0
# 1302        1        0        1        3        0         1         1
# 1124        0        0        0        0        0         0         0
# 114         3        0        1        1        0         3         0
# ...       ...      ...      ...      ...      ...       ...       ...
# 1393        3        0        0        0        0         3         1
# 1344        5        1        0        0        0         0         0
# 527         6        0        0        0        0         1         1
# 1149        2        0        0        0        0         0         0
# 1289        4        0        0        0        0         0         0
#
#       SubFPC16  SubFPC18  SubFPC23  ...  SubFPC281  SubFPC282  SubFPC287  \
# 984          0         1         1  ...          0          1          8
# 961          0         0         0  ...          0          0          2
# 1302         0         0         0  ...          0          0          4
# 1124         0         0         0  ...          0          0          4
# 114          1         0         0  ...          0          0          0
# ...        ...       ...       ...  ...        ...        ...        ...
# 1393         0         1         1  ...          0          1          8
# 1344         0         0         0  ...          0          0          5
# 527          0         0         0  ...          0          0          2
# 1149         0         1         0  ...          0          0          0
# 1289         0         0         2  ...          0          0          4
#
#       SubFPC288  SubFPC295  SubFPC296  SubFPC300  SubFPC302  SubFPC303  \
# 984           0         15          0         22          5          0
# 961           0          8          0         15          8          0
# 1302          0          6          0         12          3          1
# 1124          0          8          0          4          4          0
# 114           0         14          0         26         13          0
# ...         ...        ...        ...        ...        ...        ...
# 1393          0         15          0         22          5          0
# 1344          0          5          0         12          9          0
# 527           0         13          0         20         11          0
# 1149          0         11          0          7          2          0
# 1289          0         18          0         16          5          0
#
#       SubFPC307
# 984          21
# 961          27
# 1302         13
# 1124         16
# 114          20
# ...         ...
# 1393         21
# 1344         18
# 527          18
# 1149         13
# 1289         18
#
# [1271 rows x 44 columns]

# %%
y_train
# Out:
# 984     P
# 961     N
# 1302    P
# 1124    N
# 114     P
#        ..
# 1393    P
# 1344    N
# 527     P
# 1149    P
# 1289    P
# Name: bioactivity_class, Length: 1271, dtype: object

# %%
Training_set  = pd.concat([X_train,y_train],axis=1)
Training_set
# Out:
#       SubFPC2  SubFPC3  SubFPC4  SubFPC5  SubFPC9  SubFPC12  SubFPC15  \
# 984         3        0        0        0        0         3         1
# 961         1        1        2        0        0         0         0
# 1302        1        0        1        3        0         1         1
# 1124        0        0        0        0        0         0         0
# 114         3        0        1        1        0         3         0
# ...       ...      ...      ...      ...      ...       ...       ...
# 1393        3        0        0        0        0         3         1
# 1344        5        1        0        0        0         0         0
# 527         6        0        0        0        0         1         1
# 1149        2        0        0        0        0         0         0
# 1289        4        0        0        0        0         0         0
#
#       SubFPC16  SubFPC18  SubFPC23  ...  SubFPC282  SubFPC287  SubFPC288  \
# 984          0         1         1  ...          1          8          0
# 961          0         0         0  ...          0          2          0
# 1302         0         0         0  ...          0          4          0
# 1124         0         0         0  ...          0          4          0
# 114          1         0         0  ...          0          0          0
# ...        ...       ...       ...  ...        ...        ...        ...
# 1393         0         1         1  ...          1          8          0
# 1344         0         0         0  ...          0          5          0
# 527          0         0         0  ...          0          2          0
# 1149         0         1         0  ...          0          0          0
# 1289         0         0         2  ...          0          4          0
#
#       SubFPC295  SubFPC296  SubFPC300  SubFPC302  SubFPC303  SubFPC307  \
# 984          15          0         22          5          0         21
# 961           8          0         15          8          0         27
# 1302          6          0         12          3          1         13
# 1124          8          0          4          4          0         16
# 114          14          0         26         13          0         20
# ...         ...        ...        ...        ...        ...        ...
# 1393         15          0         22          5          0         21
# 1344          5          0         12          9          0         18
# 527          13          0         20         11          0         18
# 1149         11          0          7          2          0         13
# 1289         18          0         16          5          0         18
#
#       bioactivity_class
# 984                   P
# 961                   N
# 1302                  P
# 1124                  N
# 114                   P
# ...                 ...
# 1393                  P
# 1344                  N
# 527                   P
# 1149                  P
# 1289                  P
#
# [1271 rows x 45 columns]

# %%
Training_set.to_csv('SubstructurecountTraining_set.csv')

# %%
Testing_set  = pd.concat([X_test,y_test],axis=1)
Testing_set
# Out:
#       SubFPC2  SubFPC3  SubFPC4  SubFPC5  SubFPC9  SubFPC12  SubFPC15  \
# 1623        2        0        0        0        3         0         0
# 435         7        1        0        5        0         2         0
# 1196        1        0        0        0        0         1         1
# 1610        0        0        0        0        0         0         0
# 1014        0        0        0        0        0         0         0
# ...       ...      ...      ...      ...      ...       ...       ...
# 247         0        0        0        0        0         0         0
# 805         1        0        0        1        0         1         1
# 1396       14        6        0        4        0         1         0
# 194         2        1        0        0        0         0         0
# 1575        3        0        0        0        0         0         0
#
#       SubFPC16  SubFPC18  SubFPC23  ...  SubFPC282  SubFPC287  SubFPC288  \
# 1623         0         0         1  ...          0          2          4
# 435          3         0         0  ...          0          1          0
# 1196         0         2         0  ...          0          2          0
# 1610         0         3         0  ...          0          2          0
# 1014         0         1         0  ...          0          0          0
# ...        ...       ...       ...  ...        ...        ...        ...
# 247          2         2         0  ...          0         10          6
# 805          1         0         0  ...          1          6          0
# 1396         4         0         1  ...          1          3          0
# 194          0         4         0  ...          0          0          0
# 1575         0         1         0  ...          0          0          0
#
#       SubFPC295  SubFPC296  SubFPC300  SubFPC302  SubFPC303  SubFPC307  \
# 1623         14          0         11          5          0         23
# 435          11          0         33          3          1         20
# 1196          8          0          8          3          0         14
# 1610         14          0         10         10          1         20
# 1014         11          0          6          3          0         14
# ...         ...        ...        ...        ...        ...        ...
# 247          18          0         15         13          0         28
# 805          13          0         16          6          1         16
# 1396         38          0         74         25          0         38
# 194          20          0         21         20          0         33
# 1575          9          0          7          3          0         15
#
#       bioactivity_class
# 1623                  P
# 435                   P
# 1196                  N
# 1610                  N
# 1014                  P
# ...                 ...
# 247                   P
# 805                   P
# 1396                  N
# 194                   P
# 1575                  P
#
# [546 rows x 45 columns]

# %%
Testing_set.to_csv('SubstructurecountTesting_set.csv')

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_classif
kBest = SelectKBest(mutual_info_classif, k = 15)
X_kBestFeatures = kBest.fit_transform(X_train, y_train)
X_kBestFeatures.shape
# Out:
# (1271, 15)

# %%
kBest.get_support(True)
# Out:
# array([ 5,  9, 17, 18, 21, 23, 31, 32, 33, 35, 36, 38, 40, 41, 43])

# %%
X_kBestFeatures = Training_set.iloc[:, kBest.get_support(True)]
X_kBestFeatures.columns
# Out:
# Index(['SubFPC12', 'SubFPC23', 'SubFPC88', 'SubFPC96', 'SubFPC135',
#        'SubFPC137', 'SubFPC274', 'SubFPC275', 'SubFPC279', 'SubFPC282',
#        'SubFPC287', 'SubFPC295', 'SubFPC300', 'SubFPC302', 'SubFPC307'],
#       dtype='object')

# %%
f = kBest.get_support(1)
X_new = X_train[X_train.columns[f]]
X_new
data_scores = pd.DataFrame(kBest.scores_)
data_columns = pd.DataFrame(X.columns)

# %%
#Concat two dataframes for better visualization
featureScores = pd.concat([data_columns, data_scores], axis = 1)

#naming the dataframe columns
featureScores.columns = ['Features', 'Scores']
featureScores
# Out:
#      Features    Scores
# 0     SubFPC2  0.015798
# 1     SubFPC3  0.006126
# 2     SubFPC4  0.006350
# 3     SubFPC5  0.013203
# 4     SubFPC9  0.000000
# 5    SubFPC12  0.029531
# 6    SubFPC15  0.017943
# 7    SubFPC16  0.009226
# 8    SubFPC18  0.016438
# 9    SubFPC23  0.023910
# 10   SubFPC26  0.013735
# 11   SubFPC41  0.000000
# 12   SubFPC49  0.003830
# 13   SubFPC65  0.000000
# 14   SubFPC74  0.000000
# 15   SubFPC85  0.015130
# 16   SubFPC86  0.000000
# 17   SubFPC88  0.030308
# 18   SubFPC96  0.025787
# 19  SubFPC100  0.009689
# 20  SubFPC127  0.019957
# 21  SubFPC135  0.023344
# 22  SubFPC136  0.018641
# 23  SubFPC137  0.051558
# 24  SubFPC169  0.000000
# 25  SubFPC171  0.012355
# 26  SubFPC172  0.001813
# 27  SubFPC173  0.018233
# 28  SubFPC179  0.010722
# 29  SubFPC180  0.000000
# 30  SubFPC181  0.015841
# 31  SubFPC274  0.049066
# 32  SubFPC275  0.028678
# 33  SubFPC279  0.026786
# 34  SubFPC281  0.017386
# 35  SubFPC282  0.026706
# 36  SubFPC287  0.044114
# 37  SubFPC288  0.017848
# 38  SubFPC295  0.086322
# 39  SubFPC296  0.000000
# 40  SubFPC300  0.047647
# 41  SubFPC302  0.041916
# 42  SubFPC303  0.008904
# 43  SubFPC307  0.048673

# %%
#Print top 15 best features
print(featureScores.nlargest(15, 'Scores'))
# Out:
#      Features    Scores
# 38  SubFPC295  0.086322
# 23  SubFPC137  0.051558
# 31  SubFPC274  0.049066
# 43  SubFPC307  0.048673
# 40  SubFPC300  0.047647
# 36  SubFPC287  0.044114
# 41  SubFPC302  0.041916
# 17   SubFPC88  0.030308
# 5    SubFPC12  0.029531
# 32  SubFPC275  0.028678
# 33  SubFPC279  0.026786
# 35  SubFPC282  0.026706
# 18   SubFPC96  0.025787
# 9    SubFPC23  0.023910
# 21  SubFPC135  0.023344

# %%
Graph = (featureScores.nlargest(15, 'Scores'))
Graph
# Out:
#      Features    Scores
# 38  SubFPC295  0.086322
# 23  SubFPC137  0.051558
# 31  SubFPC274  0.049066
# 43  SubFPC307  0.048673
# 40  SubFPC300  0.047647
# 36  SubFPC287  0.044114
# 41  SubFPC302  0.041916
# 17   SubFPC88  0.030308
# 5    SubFPC12  0.029531
# 32  SubFPC275  0.028678
# 33  SubFPC279  0.026786
# 35  SubFPC282  0.026706
# 18   SubFPC96  0.025787
# 9    SubFPC23  0.023910
# 21  SubFPC135  0.023344

# %%
Graph.to_csv('SubstructurecountFeatures.csv')

# %%
import matplotlib.pyplot as plt
data = pd.read_csv('SubstructurecountFeatures.csv')
df = pd.DataFrame(data)
X = list(df.iloc[:, 1])
Y = list(df.iloc[:, 2])
plt.bar(X, Y, color='r')
plt.title("Substructurecount Feature_importance", fontweight="bold")
plt.xlabel("Features", fontweight = 'bold')
plt.ylabel("Scores", fontweight = 'bold')
plt.xticks(rotation = 80, fontweight="bold")
plt.yticks(fontweight="bold")
fig = plt.figure(figsize=(10, 10))
plt.savefig("Features.jpg", bbox_inches = 'tight')

# %%
Trainset = pd.concat([X_new,y_train],axis=1)
Trainset
# Out:
#       SubFPC12  SubFPC23  SubFPC88  SubFPC96  SubFPC135  SubFPC137  SubFPC274  \
# 984          3         1         0         0          3         12         12
# 961          0         0         2         0          0          2         18
# 1302         1         0         0         0          0          1          0
# 1124         0         0         2         0          0          3         15
# 114          3         0         3         0          0          0          6
# ...        ...       ...       ...       ...        ...        ...        ...
# 1393         3         1         0         0          3         12         12
# 1344         0         0         0         0          0          6         12
# 527          1         0         2         0          0          2         10
# 1149         0         0         0         0          0          0         15
# 1289         0         2         1         0          1          4         12
#
#       SubFPC275  SubFPC279  SubFPC282  SubFPC287  SubFPC295  SubFPC300  \
# 984           1          0          1          8         15         22
# 961           1          0          0          2          8         15
# 1302          0          1          0          4          6         12
# 1124          2          0          0          4          8          4
# 114           1          0          0          0         14         26
# ...         ...        ...        ...        ...        ...        ...
# 1393          1          0          1          8         15         22
# 1344          0          0          0          5          5         12
# 527           3          0          0          2         13         20
# 1149          4          0          0          0         11          7
# 1289          6          0          0          4         18         16
#
#       SubFPC302  SubFPC307 bioactivity_class
# 984           5         21                 P
# 961           8         27                 N
# 1302          3         13                 P
# 1124          4         16                 N
# 114          13         20                 P
# ...         ...        ...               ...
# 1393          5         21                 P
# 1344          9         18                 N
# 527          11         18                 P
# 1149          2         13                 P
# 1289          5         18                 P
#
# [1271 rows x 16 columns]

# %%
f = kBest.get_support(1)
Test_new = X_test[X_test.columns[f]]
Test_new
# Out:
#       SubFPC12  SubFPC23  SubFPC88  SubFPC96  SubFPC135  SubFPC137  SubFPC274  \
# 1623         0         1         1         0          0          2         21
# 435          2         0         1         0          0          1          0
# 1196         1         0         0         0          2          2         12
# 1610         0         0         0         0          0          0         18
# 1014         0         0         0         0          0          0         15
# ...        ...       ...       ...       ...        ...        ...        ...
# 247          0         0         0         0          0          0         24
# 805          1         0         0         0          0          0         10
# 1396         1         1         7         2          0          0          0
# 194          0         0         3         0          0          0         24
# 1575         0         0         0         0          0          0         16
#
#       SubFPC275  SubFPC279  SubFPC282  SubFPC287  SubFPC295  SubFPC300  \
# 1623          5          0          0          2         14         11
# 435           4          0          0          1         11         33
# 1196          1          0          0          2          8          8
# 1610          2          0          0          2         14         10
# 1014          3          0          0          0         11          6
# ...         ...        ...        ...        ...        ...        ...
# 247           2          0          0         10         18         15
# 805           3          0          1          6         13         16
# 1396          3          0          1          3         38         74
# 194           0          0          0          0         20         21
# 1575          2          0          0          0          9          7
#
#       SubFPC302  SubFPC307
# 1623          5         23
# 435           3         20
# 1196          3         14
# 1610         10         20
# 1014          3         14
# ...         ...        ...
# 247          13         28
# 805           6         16
# 1396         25         38
# 194          20         33
# 1575          3         15
#
# [546 rows x 15 columns]

# %%
Testset = pd.concat([Test_new,y_test],axis=1)
Testset
# Out:
#       SubFPC12  SubFPC23  SubFPC88  SubFPC96  SubFPC135  SubFPC137  SubFPC274  \
# 1623         0         1         1         0          0          2         21
# 435          2         0         1         0          0          1          0
# 1196         1         0         0         0          2          2         12
# 1610         0         0         0         0          0          0         18
# 1014         0         0         0         0          0          0         15
# ...        ...       ...       ...       ...        ...        ...        ...
# 247          0         0         0         0          0          0         24
# 805          1         0         0         0          0          0         10
# 1396         1         1         7         2          0          0          0
# 194          0         0         3         0          0          0         24
# 1575         0         0         0         0          0          0         16
#
#       SubFPC275  SubFPC279  SubFPC282  SubFPC287  SubFPC295  SubFPC300  \
# 1623          5          0          0          2         14         11
# 435           4          0          0          1         11         33
# 1196          1          0          0          2          8          8
# 1610          2          0          0          2         14         10
# 1014          3          0          0          0         11          6
# ...         ...        ...        ...        ...        ...        ...
# 247           2          0          0         10         18         15
# 805           3          0          1          6         13         16
# 1396          3          0          1          3         38         74
# 194           0          0          0          0         20         21
# 1575          2          0          0          0          9          7
#
#       SubFPC302  SubFPC307 bioactivity_class
# 1623          5         23                 P
# 435           3         20                 P
# 1196          3         14                 N
# 1610         10         20                 N
# 1014          3         14                 P
# ...         ...        ...               ...
# 247          13         28                 P
# 805           6         16                 P
# 1396         25         38                 N
# 194          20         33                 P
# 1575          3         15                 P
#
# [546 rows x 16 columns]

# %%
Trainset.to_csv('SubstructurecountTrainset_after_feature.csv')
Testset.to_csv('SubstructurecountTestset_after_feature.csv')

# %%
Trainset['bioactivity_class'].replace('N', 0, inplace=True)
Trainset['bioactivity_class'].replace('P', 1, inplace=True)
Trainset.rename(columns = {"bioactivity_class": "bioactivity_class"}, inplace = True)
Trainset
# Out:
# <ipython-input-39-4a91944d22ea>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Trainset['bioactivity_class'].replace('N', 0, inplace=True)
# <ipython-input-39-4a91944d22ea>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Trainset['bioactivity_class'].replace('P', 1, inplace=True)
# <ipython-input-39-4a91944d22ea>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Trainset['bioactivity_class'].replace('P', 1, inplace=True)
#       SubFPC12  SubFPC23  SubFPC88  SubFPC96  SubFPC135  SubFPC137  SubFPC274  \
# 984          3         1         0         0          3         12         12
# 961          0         0         2         0          0          2         18
# 1302         1         0         0         0          0          1          0
# 1124         0         0         2         0          0          3         15
# 114          3         0         3         0          0          0          6
# ...        ...       ...       ...       ...        ...        ...        ...
# 1393         3         1         0         0          3         12         12
# 1344         0         0         0         0          0          6         12
# 527          1         0         2         0          0          2         10
# 1149         0         0         0         0          0          0         15
# 1289         0         2         1         0          1          4         12
#
#       SubFPC275  SubFPC279  SubFPC282  SubFPC287  SubFPC295  SubFPC300  \
# 984           1          0          1          8         15         22
# 961           1          0          0          2          8         15
# 1302          0          1          0          4          6         12
# 1124          2          0          0          4          8          4
# 114           1          0          0          0         14         26
# ...         ...        ...        ...        ...        ...        ...
# 1393          1          0          1          8         15         22
# 1344          0          0          0          5          5         12
# 527           3          0          0          2         13         20
# 1149          4          0          0          0         11          7
# 1289          6          0          0          4         18         16
#
#       SubFPC302  SubFPC307  bioactivity_class
# 984           5         21                  1
# 961           8         27                  0
# 1302          3         13                  1
# 1124          4         16                  0
# 114          13         20                  1
# ...         ...        ...                ...
# 1393          5         21                  1
# 1344          9         18                  0
# 527          11         18                  1
# 1149          2         13                  1
# 1289          5         18                  1
#
# [1271 rows x 16 columns]

# %%
Testset['bioactivity_class'].replace('N', 0, inplace=True)
Testset['bioactivity_class'].replace('P', 1, inplace=True)
Testset.rename(columns = {"bioactivity_class": "bioactivity_class"}, inplace = True)
Testset.head()
# Out:
# <ipython-input-40-32d0d573fec9>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Testset['bioactivity_class'].replace('N', 0, inplace=True)
# <ipython-input-40-32d0d573fec9>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Testset['bioactivity_class'].replace('P', 1, inplace=True)
# <ipython-input-40-32d0d573fec9>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Testset['bioactivity_class'].replace('P', 1, inplace=True)
#       SubFPC12  SubFPC23  SubFPC88  SubFPC96  SubFPC135  SubFPC137  SubFPC274  \
# 1623         0         1         1         0          0          2         21
# 435          2         0         1         0          0          1          0
# 1196         1         0         0         0          2          2         12
# 1610         0         0         0         0          0          0         18
# 1014         0         0         0         0          0          0         15
#
#       SubFPC275  SubFPC279  SubFPC282  SubFPC287  SubFPC295  SubFPC300  \
# 1623          5          0          0          2         14         11
# 435           4          0          0          1         11         33
# 1196          1          0          0          2          8          8
# 1610          2          0          0          2         14         10
# 1014          3          0          0          0         11          6
#
#       SubFPC302  SubFPC307  bioactivity_class
# 1623          5         23                  1
# 435           3         20                  1
# 1196          3         14                  0
# 1610         10         20                  0
# 1014          3         14                  1

# %%
Trainset.to_csv('Substructurecount_Trainset1_after_feature.csv')
Testset.to_csv('Substructurecount_Testset1_after_feature.csv')
