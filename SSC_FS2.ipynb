# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhuanabala/breast-cancer/blob/feature-selection-2/SSC_FS2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('/content/SubstructureCount.csv')
data
# Out:
#                Name  SubFPC1  SubFPC2  SubFPC3  SubFPC4  SubFPC5  SubFPC6  \
# 0      CHEMBL266703        2        4        0        0        1        0
# 1     CHEMBL2145445        2        4        0        0        1        0
# 2      CHEMBL266185        2        4        0        0        1        0
# 3       CHEMBL19195        1        1        0        0        1        0
# 4          CHEMBL83        1        1        0        0        1        0
# ...             ...      ...      ...      ...      ...      ...      ...
# 1812  CHEMBL5440580        1        5        0        1        1        0
# 1813  CHEMBL5417545        1        5        0        1        0        0
# 1814   CHEMBL225542        0        0        0        0        0        0
# 1815  CHEMBL1093100        1        0        0        0        0        0
# 1816   CHEMBL428647        6        2        1        2        1        0
#
#       SubFPC7  SubFPC8  SubFPC9  ...  SubFPC299  SubFPC300  SubFPC301  \
# 0           0        0        0  ...          0         40         40
# 1           0        0        0  ...          0         29         29
# 2           0        0        0  ...          0         37         37
# 3           0        0        0  ...          0          7          7
# 4           0        0        0  ...          0          7          7
# ...       ...      ...      ...  ...        ...        ...        ...
# 1812        0        0        0  ...          0         10         10
# 1813        0        0        0  ...          0          9          9
# 1814        0        0        0  ...          0          3          3
# 1815        0        0        0  ...          0          5          5
# 1816        0        0        0  ...          0         33         33
#
#       SubFPC302  SubFPC303  SubFPC304  SubFPC305  SubFPC306  SubFPC307  \
# 0            26          0          0          0          0         52
# 1            12          0          0          0          0         42
# 2            23          0          0          0          0         52
# 3             7          0          0          0          0         21
# 4             8          0          0          0          0         21
# ...         ...        ...        ...        ...        ...        ...
# 1812          1          1          0          0          0         14
# 1813          1          1          0          0          0         14
# 1814          4          0          0          0          0         19
# 1815          2          0          0          0          0         17
# 1816         15          0          0          0          0         39
#
#       bioactivity_class
# 0                active
# 1                active
# 2                active
# 3              inactive
# 4                active
# ...                 ...
# 1812           inactive
# 1813           inactive
# 1814             active
# 1815           inactive
# 1816             active
#
# [1817 rows x 309 columns]

# %%
data.dtypes
# Out:
# Name                 object
# SubFPC1               int64
# SubFPC2               int64
# SubFPC3               int64
# SubFPC4               int64
#                       ...
# SubFPC304             int64
# SubFPC305             int64
# SubFPC306             int64
# SubFPC307             int64
# bioactivity_class    object
# Length: 309, dtype: object

# %%
data['bioactivity_class'].replace('active', 'P', inplace=True)
data['bioactivity_class'].replace('inactive', 'N', inplace=True)
data.rename(columns = {"bioactivity_class": "bioactivity_class"}, inplace = True)
data
# Out:
# <ipython-input-3-ec92a85df410>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['bioactivity_class'].replace('active', 'P', inplace=True)
# <ipython-input-3-ec92a85df410>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['bioactivity_class'].replace('inactive', 'N', inplace=True)
#                Name  SubFPC1  SubFPC2  SubFPC3  SubFPC4  SubFPC5  SubFPC6  \
# 0      CHEMBL266703        2        4        0        0        1        0
# 1     CHEMBL2145445        2        4        0        0        1        0
# 2      CHEMBL266185        2        4        0        0        1        0
# 3       CHEMBL19195        1        1        0        0        1        0
# 4          CHEMBL83        1        1        0        0        1        0
# ...             ...      ...      ...      ...      ...      ...      ...
# 1812  CHEMBL5440580        1        5        0        1        1        0
# 1813  CHEMBL5417545        1        5        0        1        0        0
# 1814   CHEMBL225542        0        0        0        0        0        0
# 1815  CHEMBL1093100        1        0        0        0        0        0
# 1816   CHEMBL428647        6        2        1        2        1        0
#
#       SubFPC7  SubFPC8  SubFPC9  ...  SubFPC299  SubFPC300  SubFPC301  \
# 0           0        0        0  ...          0         40         40
# 1           0        0        0  ...          0         29         29
# 2           0        0        0  ...          0         37         37
# 3           0        0        0  ...          0          7          7
# 4           0        0        0  ...          0          7          7
# ...       ...      ...      ...  ...        ...        ...        ...
# 1812        0        0        0  ...          0         10         10
# 1813        0        0        0  ...          0          9          9
# 1814        0        0        0  ...          0          3          3
# 1815        0        0        0  ...          0          5          5
# 1816        0        0        0  ...          0         33         33
#
#       SubFPC302  SubFPC303  SubFPC304  SubFPC305  SubFPC306  SubFPC307  \
# 0            26          0          0          0          0         52
# 1            12          0          0          0          0         42
# 2            23          0          0          0          0         52
# 3             7          0          0          0          0         21
# 4             8          0          0          0          0         21
# ...         ...        ...        ...        ...        ...        ...
# 1812          1          1          0          0          0         14
# 1813          1          1          0          0          0         14
# 1814          4          0          0          0          0         19
# 1815          2          0          0          0          0         17
# 1816         15          0          0          0          0         39
#
#       bioactivity_class
# 0                     P
# 1                     P
# 2                     P
# 3                     N
# 4                     P
# ...                 ...
# 1812                  N
# 1813                  N
# 1814                  P
# 1815                  N
# 1816                  P
#
# [1817 rows x 309 columns]

# %%
data['bioactivity_class'].replace('P', '1', inplace=True)
data['bioactivity_class'].replace('N', '0', inplace=True)
data.rename(columns = {"bioactivity_class": "bioactivity_class"}, inplace = True)
data
# Out:
# <ipython-input-4-0623c3dc39a4>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['bioactivity_class'].replace('P', '1', inplace=True)
# <ipython-input-4-0623c3dc39a4>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['bioactivity_class'].replace('N', '0', inplace=True)
#                Name  SubFPC1  SubFPC2  SubFPC3  SubFPC4  SubFPC5  SubFPC6  \
# 0      CHEMBL266703        2        4        0        0        1        0
# 1     CHEMBL2145445        2        4        0        0        1        0
# 2      CHEMBL266185        2        4        0        0        1        0
# 3       CHEMBL19195        1        1        0        0        1        0
# 4          CHEMBL83        1        1        0        0        1        0
# ...             ...      ...      ...      ...      ...      ...      ...
# 1812  CHEMBL5440580        1        5        0        1        1        0
# 1813  CHEMBL5417545        1        5        0        1        0        0
# 1814   CHEMBL225542        0        0        0        0        0        0
# 1815  CHEMBL1093100        1        0        0        0        0        0
# 1816   CHEMBL428647        6        2        1        2        1        0
#
#       SubFPC7  SubFPC8  SubFPC9  ...  SubFPC299  SubFPC300  SubFPC301  \
# 0           0        0        0  ...          0         40         40
# 1           0        0        0  ...          0         29         29
# 2           0        0        0  ...          0         37         37
# 3           0        0        0  ...          0          7          7
# 4           0        0        0  ...          0          7          7
# ...       ...      ...      ...  ...        ...        ...        ...
# 1812        0        0        0  ...          0         10         10
# 1813        0        0        0  ...          0          9          9
# 1814        0        0        0  ...          0          3          3
# 1815        0        0        0  ...          0          5          5
# 1816        0        0        0  ...          0         33         33
#
#       SubFPC302  SubFPC303  SubFPC304  SubFPC305  SubFPC306  SubFPC307  \
# 0            26          0          0          0          0         52
# 1            12          0          0          0          0         42
# 2            23          0          0          0          0         52
# 3             7          0          0          0          0         21
# 4             8          0          0          0          0         21
# ...         ...        ...        ...        ...        ...        ...
# 1812          1          1          0          0          0         14
# 1813          1          1          0          0          0         14
# 1814          4          0          0          0          0         19
# 1815          2          0          0          0          0         17
# 1816         15          0          0          0          0         39
#
#       bioactivity_class
# 0                     1
# 1                     1
# 2                     1
# 3                     0
# 4                     1
# ...                 ...
# 1812                  0
# 1813                  0
# 1814                  1
# 1815                  0
# 1816                  1
#
# [1817 rows x 309 columns]

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.dropna(inplace =True)
data.isnull().sum().sum()
# Out:
# 0

# %%
data1 = data.iloc[:,1:308]
data1
data2 = data.iloc[:,-1]

# %%
data1
data2
# Out:
# 0       1
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 1812    0
# 1813    0
# 1814    1
# 1815    0
# 1816    1
# Name: bioactivity_class, Length: 1817, dtype: object

# %%
from sklearn.feature_selection import VarianceThreshold
threshold = VarianceThreshold(threshold=.1)
def variance_threshold_selector(data1, threshold=0.10):
    selector = VarianceThreshold(threshold)
    selector.fit(data1)
    return data[data1.columns[selector.get_support(indices=True)]]
data1_HV = variance_threshold_selector(data1)

# %%
data1_HV = variance_threshold_selector(data1)
data1_HV
# Out:
#       SubFPC1  SubFPC2  SubFPC3  SubFPC4  SubFPC5  SubFPC9  SubFPC12  \
# 0           2        4        0        0        1        0         3
# 1           2        4        0        0        1        0         3
# 2           2        4        0        0        1        0         3
# 3           1        1        0        0        1        0         0
# 4           1        1        0        0        1        0         0
# ...       ...      ...      ...      ...      ...      ...       ...
# 1812        1        5        0        1        1        0         0
# 1813        1        5        0        1        0        0         0
# 1814        0        0        0        0        0        0         0
# 1815        1        0        0        0        0        0         0
# 1816        6        2        1        2        1        0         3
#
#       SubFPC14  SubFPC15  SubFPC16  ...  SubFPC286  SubFPC287  SubFPC288  \
# 0            1         1         1  ...          1         18          0
# 1            1         1         0  ...          1         14          0
# 2            1         1         0  ...          1         18          0
# 3            0         0         0  ...          0          6          0
# 4            0         0         0  ...          0          6          0
# ...        ...       ...       ...  ...        ...        ...        ...
# 1812         0         0         0  ...          0          3          0
# 1813         0         0         0  ...          0          3          0
# 1814         0         0         0  ...          0          2          0
# 1815         0         0         0  ...          0          0          0
# 1816         2         1         1  ...          0          4          0
#
#       SubFPC295  SubFPC296  SubFPC300  SubFPC301  SubFPC302  SubFPC303  \
# 0            30          0         40         40         26          0
# 1            21          0         29         29         12          0
# 2            28          0         37         37         23          0
# 3             6          0          7          7          7          0
# 4             5          0          7          7          8          0
# ...         ...        ...        ...        ...        ...        ...
# 1812          8          0         10         10          1          1
# 1813          8          0          9          9          1          1
# 1814         12          0          3          3          4          0
# 1815         10          0          5          5          2          0
# 1816         21          0         33         33         15          0
#
#       SubFPC307
# 0            52
# 1            42
# 2            52
# 3            21
# 4            21
# ...         ...
# 1812         14
# 1813         14
# 1814         19
# 1815         17
# 1816         39
#
# [1817 rows x 54 columns]

# %%
data2_HV = pd.merge(data1_HV,data2,left_index=True,right_index=True)
data2_HV
# Out:
#       SubFPC1  SubFPC2  SubFPC3  SubFPC4  SubFPC5  SubFPC9  SubFPC12  \
# 0           2        4        0        0        1        0         3
# 1           2        4        0        0        1        0         3
# 2           2        4        0        0        1        0         3
# 3           1        1        0        0        1        0         0
# 4           1        1        0        0        1        0         0
# ...       ...      ...      ...      ...      ...      ...       ...
# 1812        1        5        0        1        1        0         0
# 1813        1        5        0        1        0        0         0
# 1814        0        0        0        0        0        0         0
# 1815        1        0        0        0        0        0         0
# 1816        6        2        1        2        1        0         3
#
#       SubFPC14  SubFPC15  SubFPC16  ...  SubFPC287  SubFPC288  SubFPC295  \
# 0            1         1         1  ...         18          0         30
# 1            1         1         0  ...         14          0         21
# 2            1         1         0  ...         18          0         28
# 3            0         0         0  ...          6          0          6
# 4            0         0         0  ...          6          0          5
# ...        ...       ...       ...  ...        ...        ...        ...
# 1812         0         0         0  ...          3          0          8
# 1813         0         0         0  ...          3          0          8
# 1814         0         0         0  ...          2          0         12
# 1815         0         0         0  ...          0          0         10
# 1816         2         1         1  ...          4          0         21
#
#       SubFPC296  SubFPC300  SubFPC301  SubFPC302  SubFPC303  SubFPC307  \
# 0             0         40         40         26          0         52
# 1             0         29         29         12          0         42
# 2             0         37         37         23          0         52
# 3             0          7          7          7          0         21
# 4             0          7          7          8          0         21
# ...         ...        ...        ...        ...        ...        ...
# 1812          0         10         10          1          1         14
# 1813          0          9          9          1          1         14
# 1814          0          3          3          4          0         19
# 1815          0          5          5          2          0         17
# 1816          0         33         33         15          0         39
#
#       bioactivity_class
# 0                     1
# 1                     1
# 2                     1
# 3                     0
# 4                     1
# ...                 ...
# 1812                  0
# 1813                  0
# 1814                  1
# 1815                  0
# 1816                  1
#
# [1817 rows x 55 columns]

# %%
correlated_features_1 = set()
corr_matrix_class = data2_HV.drop(columns=['bioactivity_class']).corr()


for i in range(len(corr_matrix_class.columns)):
    for j in range(i):
        if abs(corr_matrix_class.iloc[i, j]) > 0.9:
            colname = corr_matrix_class.columns[i]
            correlated_features_1.add(colname)
correlated_features_1
# Out:
# {'SubFPC101',
#  'SubFPC14',
#  'SubFPC184',
#  'SubFPC280',
#  'SubFPC283',
#  'SubFPC285',
#  'SubFPC286',
#  'SubFPC301',
#  'SubFPC66'}

# %%
def remove_correlated_features(features, data):
    for x in features:
        data.drop(x, axis=1, inplace=True)
    return data

# %%
data3= remove_correlated_features(correlated_features_1, data2_HV)
data3
# Out:
#       SubFPC1  SubFPC2  SubFPC3  SubFPC4  SubFPC5  SubFPC9  SubFPC12  \
# 0           2        4        0        0        1        0         3
# 1           2        4        0        0        1        0         3
# 2           2        4        0        0        1        0         3
# 3           1        1        0        0        1        0         0
# 4           1        1        0        0        1        0         0
# ...       ...      ...      ...      ...      ...      ...       ...
# 1812        1        5        0        1        1        0         0
# 1813        1        5        0        1        0        0         0
# 1814        0        0        0        0        0        0         0
# 1815        1        0        0        0        0        0         0
# 1816        6        2        1        2        1        0         3
#
#       SubFPC15  SubFPC16  SubFPC18  ...  SubFPC282  SubFPC287  SubFPC288  \
# 0            1         1         2  ...          1         18          0
# 1            1         0         1  ...          1         14          0
# 2            1         0         2  ...          1         18          0
# 3            0         0         0  ...          0          6          0
# 4            0         0         1  ...          0          6          0
# ...        ...       ...       ...  ...        ...        ...        ...
# 1812         0         0         0  ...          0          3          0
# 1813         0         0         0  ...          0          3          0
# 1814         0         0         0  ...          0          2          0
# 1815         0         0         0  ...          0          0          0
# 1816         1         1         0  ...          0          4          0
#
#       SubFPC295  SubFPC296  SubFPC300  SubFPC302  SubFPC303  SubFPC307  \
# 0            30          0         40         26          0         52
# 1            21          0         29         12          0         42
# 2            28          0         37         23          0         52
# 3             6          0          7          7          0         21
# 4             5          0          7          8          0         21
# ...         ...        ...        ...        ...        ...        ...
# 1812          8          0         10          1          1         14
# 1813          8          0          9          1          1         14
# 1814         12          0          3          4          0         19
# 1815         10          0          5          2          0         17
# 1816         21          0         33         15          0         39
#
#       bioactivity_class
# 0                     1
# 1                     1
# 2                     1
# 3                     0
# 4                     1
# ...                 ...
# 1812                  0
# 1813                  0
# 1814                  1
# 1815                  0
# 1816                  1
#
# [1817 rows x 46 columns]

# %%
data3.to_csv('ssc2.csv')

# %%
X = data3.iloc[:,1:45]  #independent columns
X
y = data3.iloc[:,-1]
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 1812    0
# 1813    0
# 1814    1
# 1815    0
# 1816    1
# Name: bioactivity_class, Length: 1817, dtype: object

# %%
X
# Out:
#       SubFPC2  SubFPC3  SubFPC4  SubFPC5  SubFPC9  SubFPC12  SubFPC15  \
# 0           4        0        0        1        0         3         1
# 1           4        0        0        1        0         3         1
# 2           4        0        0        1        0         3         1
# 3           1        0        0        1        0         0         0
# 4           1        0        0        1        0         0         0
# ...       ...      ...      ...      ...      ...       ...       ...
# 1812        5        0        1        1        0         0         0
# 1813        5        0        1        0        0         0         0
# 1814        0        0        0        0        0         0         0
# 1815        0        0        0        0        0         0         0
# 1816        2        1        2        1        0         3         1
#
#       SubFPC16  SubFPC18  SubFPC23  ...  SubFPC281  SubFPC282  SubFPC287  \
# 0            1         2         1  ...          0          1         18
# 1            0         1         1  ...          0          1         14
# 2            0         2         1  ...          0          1         18
# 3            0         0         0  ...          0          0          6
# 4            0         1         1  ...          0          0          6
# ...        ...       ...       ...  ...        ...        ...        ...
# 1812         0         0         0  ...          0          0          3
# 1813         0         0         0  ...          0          0          3
# 1814         0         0         0  ...          0          0          2
# 1815         0         0         0  ...          0          0          0
# 1816         1         0         0  ...          0          0          4
#
#       SubFPC288  SubFPC295  SubFPC296  SubFPC300  SubFPC302  SubFPC303  \
# 0             0         30          0         40         26          0
# 1             0         21          0         29         12          0
# 2             0         28          0         37         23          0
# 3             0          6          0          7          7          0
# 4             0          5          0          7          8          0
# ...         ...        ...        ...        ...        ...        ...
# 1812          0          8          0         10          1          1
# 1813          0          8          0          9          1          1
# 1814          0         12          0          3          4          0
# 1815          0         10          0          5          2          0
# 1816          0         21          0         33         15          0
#
#       SubFPC307
# 0            52
# 1            42
# 2            52
# 3            21
# 4            21
# ...         ...
# 1812         14
# 1813         14
# 1814         19
# 1815         17
# 1816         39
#
# [1817 rows x 44 columns]

# %%
from sklearn.preprocessing import StandardScaler
# y = data['class']
# X_features =data.drop(columns='class')
scaler = StandardScaler()
X_transform = scaler.fit_transform(X)
X_transform_pd = pd.DataFrame(X_transform, columns = X.columns)
X_transform_pd

# #Standardize/normalize the data
# from sklearn.preprocessing import MinMaxScaler
# sc = MinMaxScaler()
# X_transform = sc.fit_transform(X)
# X_transform
# Out:
#        SubFPC2   SubFPC3   SubFPC4   SubFPC5   SubFPC9  SubFPC12  SubFPC15  \
# 0     0.454333 -0.488479 -0.390203  0.480001 -0.227062  1.687391  2.160167
# 1     0.454333 -0.488479 -0.390203  0.480001 -0.227062  1.687391  2.160167
# 2     0.454333 -0.488479 -0.390203  0.480001 -0.227062  1.687391  2.160167
# 3    -0.432056 -0.488479 -0.390203  0.480001 -0.227062 -0.430980 -0.386896
# 4    -0.432056 -0.488479 -0.390203  0.480001 -0.227062 -0.430980 -0.386896
# ...        ...       ...       ...       ...       ...       ...       ...
# 1812  0.749796 -0.488479  0.860235  0.480001 -0.227062 -0.430980 -0.386896
# 1813  0.749796 -0.488479  0.860235 -0.511092 -0.227062 -0.430980 -0.386896
# 1814 -0.727519 -0.488479 -0.390203 -0.511092 -0.227062 -0.430980 -0.386896
# 1815 -0.727519 -0.488479 -0.390203 -0.511092 -0.227062 -0.430980 -0.386896
# 1816 -0.136593  0.405344  2.110673  0.480001 -0.227062  1.687391  2.160167
#
#       SubFPC16  SubFPC18  SubFPC23  ...  SubFPC281  SubFPC282  SubFPC287  \
# 0     1.431626  1.409157  1.255569  ...  -0.138804   1.868388   4.806178
# 1    -0.330748  0.401507  1.255569  ...  -0.138804   1.868388   3.504569
# 2    -0.330748  1.409157  1.255569  ...  -0.138804   1.868388   4.806178
# 3    -0.330748 -0.606143 -0.371656  ...  -0.138804  -0.223332   0.901349
# 4    -0.330748  0.401507  1.255569  ...  -0.138804  -0.223332   0.901349
# ...        ...       ...       ...  ...        ...        ...        ...
# 1812 -0.330748 -0.606143 -0.371656  ...  -0.138804  -0.223332  -0.074859
# 1813 -0.330748 -0.606143 -0.371656  ...  -0.138804  -0.223332  -0.074859
# 1814 -0.330748 -0.606143 -0.371656  ...  -0.138804  -0.223332  -0.400261
# 1815 -0.330748 -0.606143 -0.371656  ...  -0.138804  -0.223332  -1.051066
# 1816  1.431626 -0.606143 -0.371656  ...  -0.138804  -0.223332   0.250544
#
#       SubFPC288  SubFPC295  SubFPC296  SubFPC300  SubFPC302  SubFPC303  \
# 0     -0.226324   2.346288  -0.245422   1.816050    2.58812  -0.364264
# 1     -0.226324   1.183631  -0.245422   1.018200    0.74530  -0.364264
# 2     -0.226324   2.087920  -0.245422   1.598455    2.19323  -0.364264
# 3     -0.226324  -0.754131  -0.245422  -0.577500    0.08715  -0.364264
# 4     -0.226324  -0.883315  -0.245422  -0.577500    0.21878  -0.364264
# ...         ...        ...        ...        ...        ...        ...
# 1812  -0.226324  -0.495763  -0.245422  -0.359905   -0.70263   0.485374
# 1813  -0.226324  -0.495763  -0.245422  -0.432437   -0.70263   0.485374
# 1814  -0.226324   0.020974  -0.245422  -0.867628   -0.30774  -0.364264
# 1815  -0.226324  -0.237395  -0.245422  -0.722564   -0.57100  -0.364264
# 1816  -0.226324   1.183631  -0.245422   1.308327    1.14019  -0.364264
#
#       SubFPC307
# 0      3.458326
# 1      2.377859
# 2      3.458326
# 3      0.108879
# 4      0.108879
# ...         ...
# 1812  -0.647448
# 1813  -0.647448
# 1814  -0.107214
# 1815  -0.323308
# 1816   2.053719
#
# [1817 rows x 44 columns]

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_classif
kBest = SelectKBest(mutual_info_classif, k = 15)
X_kBestFeatures = kBest.fit_transform(X,y)
X_kBestFeatures.shape
# Out:
# (1817, 15)

# %%
kBest.get_support(True)
# Out:
# array([ 5,  6, 13, 14, 22, 23, 25, 30, 31, 32, 36, 38, 40, 41, 43])

# %%
X_kBestFeatures = X.iloc[:, kBest.get_support(True)]
X_kBestFeatures.columns
# Out:
# Index(['SubFPC12', 'SubFPC15', 'SubFPC65', 'SubFPC74', 'SubFPC136',
#        'SubFPC137', 'SubFPC171', 'SubFPC181', 'SubFPC274', 'SubFPC275',
#        'SubFPC287', 'SubFPC295', 'SubFPC300', 'SubFPC302', 'SubFPC307'],
#       dtype='object')

# %%
f = kBest.get_support(1)
X_new = X[X.columns[f]]
X_new
data_scores = pd.DataFrame(kBest.scores_)
data_columns = pd.DataFrame(X.columns)

# %%
featureScores = pd.concat([data_columns, data_scores], axis = 1)

#naming the dataframe columns
featureScores.columns = ['Features', 'Scores']
featureScores
# Out:
#      Features    Scores
# 0     SubFPC2  0.023032
# 1     SubFPC3  0.000000
# 2     SubFPC4  0.020970
# 3     SubFPC5  0.015061
# 4     SubFPC9  0.004784
# 5    SubFPC12  0.030678
# 6    SubFPC15  0.029872
# 7    SubFPC16  0.003218
# 8    SubFPC18  0.000000
# 9    SubFPC23  0.000000
# 10   SubFPC26  0.004225
# 11   SubFPC41  0.010627
# 12   SubFPC49  0.020006
# 13   SubFPC65  0.024550
# 14   SubFPC74  0.028528
# 15   SubFPC85  0.022842
# 16   SubFPC86  0.000000
# 17   SubFPC88  0.009089
# 18   SubFPC96  0.007771
# 19  SubFPC100  0.009612
# 20  SubFPC127  0.017729
# 21  SubFPC135  0.004784
# 22  SubFPC136  0.024895
# 23  SubFPC137  0.058234
# 24  SubFPC169  0.001946
# 25  SubFPC171  0.030156
# 26  SubFPC172  0.000000
# 27  SubFPC173  0.019162
# 28  SubFPC179  0.011470
# 29  SubFPC180  0.024190
# 30  SubFPC181  0.034979
# 31  SubFPC274  0.037664
# 32  SubFPC275  0.027648
# 33  SubFPC279  0.000000
# 34  SubFPC281  0.000000
# 35  SubFPC282  0.003494
# 36  SubFPC287  0.036094
# 37  SubFPC288  0.004174
# 38  SubFPC295  0.062774
# 39  SubFPC296  0.020370
# 40  SubFPC300  0.044442
# 41  SubFPC302  0.045069
# 42  SubFPC303  0.015086
# 43  SubFPC307  0.047558

# %%
#Print top 15 best features
print(featureScores.nlargest(15, 'Scores'))
# Out:
#      Features    Scores
# 38  SubFPC295  0.062774
# 23  SubFPC137  0.058234
# 43  SubFPC307  0.047558
# 41  SubFPC302  0.045069
# 40  SubFPC300  0.044442
# 31  SubFPC274  0.037664
# 36  SubFPC287  0.036094
# 30  SubFPC181  0.034979
# 5    SubFPC12  0.030678
# 25  SubFPC171  0.030156
# 6    SubFPC15  0.029872
# 14   SubFPC74  0.028528
# 32  SubFPC275  0.027648
# 22  SubFPC136  0.024895
# 13   SubFPC65  0.024550

# %%
Graph = (featureScores.nlargest(15, 'Scores'))
Graph
# Out:
#      Features    Scores
# 38  SubFPC295  0.062774
# 23  SubFPC137  0.058234
# 43  SubFPC307  0.047558
# 41  SubFPC302  0.045069
# 40  SubFPC300  0.044442
# 31  SubFPC274  0.037664
# 36  SubFPC287  0.036094
# 30  SubFPC181  0.034979
# 5    SubFPC12  0.030678
# 25  SubFPC171  0.030156
# 6    SubFPC15  0.029872
# 14   SubFPC74  0.028528
# 32  SubFPC275  0.027648
# 22  SubFPC136  0.024895
# 13   SubFPC65  0.024550

# %%
Graph.to_csv('SSC2.csv')

# %%
import matplotlib.pyplot as plt
data = pd.read_csv('SSC2.csv')
df = pd.DataFrame(data)
X = list(df.iloc[:, 1])
Y = list(df.iloc[:, 2])
plt.bar(X, Y, color='r')
plt.title("Substructurecount Feature_importance", fontweight="bold")
plt.xlabel("Features", fontweight = 'bold')
plt.ylabel("Scores", fontweight = 'bold')
plt.xticks(rotation = 80, fontweight="bold")
plt.yticks(fontweight="bold")
fig = plt.figure(figsize=(10, 10))
plt.savefig("Features.jpg", bbox_inches = 'tight')

# %%
SSC_FS2 = pd.concat([X_new,y],axis=1)
SSC_FS2
# Out:
#       SubFPC12  SubFPC15  SubFPC65  SubFPC74  SubFPC136  SubFPC137  SubFPC171  \
# 0            3         1         1         0          3         14          0
# 1            3         1         0         0          2         12          0
# 2            3         1         1         0          3         14          0
# 3            0         0         0         0          0          0          0
# 4            0         0         0         0          0          0          0
# ...        ...       ...       ...       ...        ...        ...        ...
# 1812         0         0         0         0          0          2          0
# 1813         0         0         0         0          0          2          0
# 1814         0         0         0         0          0          0          0
# 1815         0         0         0         0          0          0          0
# 1816         3         1         0         0          0          4          0
#
#       SubFPC181  SubFPC274  SubFPC275  SubFPC287  SubFPC295  SubFPC300  \
# 0             0         36          1         18         30         40
# 1             0         30          1         14         21         29
# 2             0         36          1         18         28         37
# 3             0         18          0          6          6          7
# 4             0         18          0          6          5          7
# ...         ...        ...        ...        ...        ...        ...
# 1812          0          6          2          3          8         10
# 1813          0          6          2          3          8          9
# 1814          3         19          4          2         12          3
# 1815          2         19          3          0         10          5
# 1816          0         18          1          4         21         33
#
#       SubFPC302  SubFPC307 bioactivity_class
# 0            26         52                 1
# 1            12         42                 1
# 2            23         52                 1
# 3             7         21                 0
# 4             8         21                 1
# ...         ...        ...               ...
# 1812          1         14                 0
# 1813          1         14                 0
# 1814          4         19                 1
# 1815          2         17                 0
# 1816         15         39                 1
#
# [1817 rows x 16 columns]

# %%
SSC_FS2.to_csv('SSCFS2_after_feature.csv')
